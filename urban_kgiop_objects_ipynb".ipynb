# %% [markdown]
# <a href="https://colab.research.google.com/github/aniaprokosheva/urban_kgiop_objects/blob/main/urban_kgiop_objects_ipynb%22.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Проект: Улицы. Объекты культурного наследия.

# %% [markdown]
# **Цель исследования:** отобразить объкты культурного наследия для улиц в выбранном районе Санкт-Петербурга.
# * KGIOP - Комитет по государственному контролю, использованию и охране памятников истории и культуры
#
# **Библиотеки:** pandas, geopandas, osmnx
#
# **Содержание:**
# 1. Общая информация (загрузка модулей и библиотек, константы и функции)
# 2. Территория Санкт-Петербурга
# 3. Улицы, которые входят в выбранный район.
# 4. Объекты культурного наследия выбранной территории.
#     4.3. Количество объектов, попадающие в заданный буфер вокруг улицы.
# 5. Выводы
# 6. Сохранение файлов

# %% [markdown]
# ## 1 Общая информация

# %%
#дополнительные модули
# !pip install folium -U
# !pip install geopandas mapclassify osmnx
# Out:
# Requirement already satisfied: folium in /usr/local/lib/python3.10/dist-packages (0.14.0)
# Requirement already satisfied: branca>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from folium) (0.6.0)
# Requirement already satisfied: jinja2>=2.9 in /usr/local/lib/python3.10/dist-packages (from folium) (3.1.2)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from folium) (1.22.4)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from folium) (2.27.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2>=2.9->folium) (2.1.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->folium) (3.4)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.10/dist-packages (0.13.2)
# Collecting mapclassify
#   Downloading mapclassify-2.5.0-py3-none-any.whl (39 kB)
# Collecting osmnx
#   Downloading osmnx-1.5.0-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.0/98.0 kB 4.1 MB/s eta 0:00:00
# Requirement already satisfied: fiona>=1.8.19 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.9.4.post1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from geopandas) (23.1)
# Requirement already satisfied: pandas>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from geopandas) (1.5.3)
# Requirement already satisfied: pyproj>=3.0.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (3.6.0)
# Requirement already satisfied: shapely>=1.7.1 in /usr/local/lib/python3.10/dist-packages (from geopandas) (2.0.1)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.10.1)
# Requirement already satisfied: numpy>=1.3 in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.22.4)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from mapclassify) (1.2.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from mapclassify) (3.1)
# Requirement already satisfied: requests>=2.25 in /usr/local/lib/python3.10/dist-packages (from osmnx) (2.27.1)
# Requirement already satisfied: attrs>=19.2.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (23.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (2023.5.7)
# Requirement already satisfied: click~=8.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (8.1.3)
# Requirement already satisfied: click-plugins>=1.0 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (0.7.2)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fiona>=1.8.19->geopandas) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.0->geopandas) (2022.7.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25->osmnx) (1.26.16)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25->osmnx) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.25->osmnx) (3.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->mapclassify) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->mapclassify) (3.1.0)
# Installing collected packages: mapclassify, osmnx
# Successfully installed mapclassify-2.5.0 osmnx-1.5.0

# %%
#установка библиотек
import pandas as pd
import geopandas as gpd
import osmnx as ox

# %%
#все константs, использованные в проекте
TILES = "CartoDB positron" #подложка карт

TERRITORY_NAME = 'Красногвардейский район, Санкт-Петербург' #выбранный район
STREETS_FILE_URL = "https://drive.google.com/file/d/1bUT1E-QSbG1vpSNM2dOG2-LEVXSrPdo3/view?usp=sharing" #слой с улицами, которые входят в выбранный район
KGIOP_FILE_URL = "https://raw.githubusercontent.com/aeksei/python-urban/main/kgiop_objects.geojson" #слой с объектами культурного наследия

# %%
# функция, позволяющая читать ссылку для скачивания с google drive
def get_google_drive_download_url(url: str) -> str:
    """
    Функция возвращает ссылку для скачивания с google drive.
    """
    drive_id = url.split("/")[5]
    return f"https://drive.google.com/uc?export=download&id={drive_id}"

# %% [markdown]
# ## 2 Территория

# %% [markdown]
# ### 2.1 Загрузка территории из OSM (Extract)

# %%
#подгружаем территорию с OSM и получаем GeoDataFrame с помощью `ox.geocode_to_gdf()
territory = ox.geocode_to_gdf(TERRITORY_NAME)
territory.explore(tiles=TILES)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1fc24291973167ea5e55cc6cc101df0b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1fc24291973167ea5e55cc6cc101df0b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1fc24291973167ea5e55cc6cc101df0b = L.map(
#                 &quot;map_1fc24291973167ea5e55cc6cc101df0b&quot;,
#                 {
#                     center: [59.978188450000005, 30.48015535],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_1fc24291973167ea5e55cc6cc101df0b);
#
#
#
#
#
#             var tile_layer_fffd112e4bef0ef9c8bc7e983c787a20 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_1fc24291973167ea5e55cc6cc101df0b);
#
#
#             map_1fc24291973167ea5e55cc6cc101df0b.fitBounds(
#                 [[59.9154313, 30.3942814], [60.0409456, 30.5660293]],
#                 {}
#             );
#
#
#         function geo_json_8f19cbe613c2849f8e4537d3ebc2aa5a_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_8f19cbe613c2849f8e4537d3ebc2aa5a_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_8f19cbe613c2849f8e4537d3ebc2aa5a_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_8f19cbe613c2849f8e4537d3ebc2aa5a_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_8f19cbe613c2849f8e4537d3ebc2aa5a_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_8f19cbe613c2849f8e4537d3ebc2aa5a.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_8f19cbe613c2849f8e4537d3ebc2aa5a_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_8f19cbe613c2849f8e4537d3ebc2aa5a = L.geoJson(null, {
#                 onEachFeature: geo_json_8f19cbe613c2849f8e4537d3ebc2aa5a_onEachFeature,
#
#                 style: geo_json_8f19cbe613c2849f8e4537d3ebc2aa5a_styler,
#                 pointToLayer: geo_json_8f19cbe613c2849f8e4537d3ebc2aa5a_pointToLayer
#         });
#
#         function geo_json_8f19cbe613c2849f8e4537d3ebc2aa5a_add (data) {
#             geo_json_8f19cbe613c2849f8e4537d3ebc2aa5a
#                 .addData(data)
#                 .addTo(map_1fc24291973167ea5e55cc6cc101df0b);
#         }
#             geo_json_8f19cbe613c2849f8e4537d3ebc2aa5a_add({&quot;bbox&quot;: [30.3942814, 59.9154313, 30.5660293, 60.0409456], &quot;features&quot;: [{&quot;bbox&quot;: [30.3942814, 59.9154313, 30.5660293, 60.0409456], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[30.3942814, 59.9290236], [30.3959056, 59.9257386], [30.397196, 59.9241878], [30.4022068, 59.9206316], [30.4068447, 59.917672], [30.4094032, 59.9154313], [30.4131736, 59.9165073], [30.416004, 59.9171213], [30.4217225, 59.9186916], [30.4214543, 59.9185303], [30.4217225, 59.918455], [30.42303

# %% [markdown]
# ## 3 Улицы

# %% [markdown]
# ### 3.1 Загрузка файла с улицами из google drive

# %%
url = get_google_drive_download_url(STREETS_FILE_URL)
gdf_streets = gpd.read_file(url, mask=territory)  # фильтр улиц по маске геометрии территории, полученной ранее
gdf_streets
# Out:
#      type         id                                               tags  \
# 0     way    4078548  {'foot': 'no', 'highway': 'residential', 'lane...
# 1     way    4454334  {'highway': 'tertiary', 'junction': 'roundabou...
# 2     way    4454660  {'foot': 'no', 'highway': 'primary', 'lanes': ...
# 3     way    4454692  {'highway': 'unclassified', 'lanes': '2', 'lit...
# 4     way    4455562  {'highway': 'secondary', 'lanes': '2', 'layer'...
# ...   ...        ...                                                ...
# 6316  way  981878572                             {'highway': 'service'}
# 6317  way  982791402       {'highway': 'service', 'surface': 'asphalt'}
# 6318  way  982791403  {'highway': 'residential', 'lanes': '1', 'lit'...
# 6319  way  982791404  {'highway': 'residential', 'lanes': '1', 'lit'...
# 6320  way  982791405  {'highway': 'residential', 'lanes': '2', 'lit'...
#
#                                                geometry
# 0     LINESTRING (3385685.754 8387961.891, 3385692.2...
# 1     LINESTRING (3388641.888 8396122.519, 3388624.9...
# 2     LINESTRING (3388144.278 8393976.488, 3388156.8...
# 3     LINESTRING (3386659.454 8393215.475, 3386629.8...
# 4     LINESTRING (3390821.701 8403547.048, 3390778.0...
# ...                                                 ...
# 6316  LINESTRING (3390484.437 8390881.717, 3390544.7...
# 6317  LINESTRING (3390016.116 8405605.740, 3390030.0...
# 6318  LINESTRING (3390016.116 8405605.740, 3390104.3...
# 6319  LINESTRING (3389902.759 8405833.105, 3390016.1...
# 6320  LINESTRING (3389725.572 8406231.547, 3389622.1...
#
# [6321 rows x 4 columns]

# %% [markdown]
# ### 3.2 Обработка данных с улицами

# %%
tags = pd.json_normalize(gdf_streets["tags"]) # json_normalize позволяет преобразовать вложенные структуры данных в json файле в таблицу
tags
# Out:
#      foot       highway lanes  lit  maxspeed                     name oneway  \
# 0      no   residential     2  yes  RU:urban        Шепетовская улица    yes
# 1     NaN      tertiary     1  yes  RU:urban  Екатерининский проспект    yes
# 2      no       primary     3  yes  RU:urban     проспект Энергетиков    yes
# 3     NaN  unclassified     2   no  RU:urban                      NaN    NaN
# 4     NaN     secondary     2  yes  RU:rural    Пискарёвский проспект    yes
# ...   ...           ...   ...  ...       ...                      ...    ...
# 6316  NaN       service   NaN  NaN       NaN                      NaN    NaN
# 6317  NaN       service   NaN  NaN       NaN                      NaN    NaN
# 6318  NaN   residential     1  yes        20         проспект Маршака    yes
# 6319  NaN   residential     1  yes        40         проспект Маршака    yes
# 6320  NaN   residential     2  yes  RU:urban         проспект Маршака    yes
#
#      postal_code  surface    junction  ... parking:lane:right:time_interval  \
# 0         195027  asphalt         NaN  ...                              NaN
# 1            NaN  asphalt  roundabout  ...                              NaN
# 2            NaN  asphalt         NaN  ...                              NaN
# 3            NaN  asphalt         NaN  ...                              NaN
# 4            NaN  asphalt         NaN  ...                              NaN
# ...          ...      ...         ...  ...                              ...
# 6316         NaN      NaN         NaN  ...                              NaN
# 6317         NaN  asphalt         NaN  ...                              NaN
# 6318         NaN  asphalt         NaN  ...                              NaN
# 6319         NaN  asphalt         NaN  ...                              NaN
# 6320         NaN  asphalt         NaN  ...                              NaN
#
#      motor_vehicle placement busway cycleway:right  bus bicycle horse footway  \
# 0              NaN       NaN    NaN            NaN  NaN     NaN   NaN     NaN
# 1              NaN       NaN    NaN            NaN  NaN     NaN   NaN     NaN
# 2              NaN       NaN    NaN            NaN  NaN     NaN   NaN     NaN
# 3              NaN       NaN    NaN            NaN  NaN     NaN   NaN     NaN
# 4              NaN       NaN    NaN            NaN  NaN     NaN   NaN     NaN
# ...            ...       ...    ...            ...  ...     ...   ...     ...
# 6316           NaN       NaN    NaN            NaN  NaN     NaN   NaN     NaN
# 6317           NaN       NaN    NaN            NaN  NaN     NaN   NaN     NaN
# 6318           NaN       NaN    NaN            NaN  NaN     NaN   NaN     NaN
# 6319           NaN       NaN    NaN            NaN  NaN     NaN   NaN     NaN
# 6320           NaN       NaN    NaN            NaN  NaN     NaN   NaN     NaN
#
#      noexit
# 0       NaN
# 1       NaN
# 2       NaN
# 3       NaN
# 4       NaN
# ...     ...
# 6316    NaN
# 6317    NaN
# 6318    NaN
# 6319    NaN
# 6320    NaN
#
# [6321 rows x 94 columns]

# %%
tags.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6321 entries, 0 to 6320
# Data columns (total 94 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   foot                              846 non-null    object
#  1   highway                           6321 non-null   object
#  2   lanes                             1432 non-null   object
#  3   lit                               1496 non-null   object
#  4   maxspeed                          1468 non-null   object
#  5   name                              1340 non-null   object
#  6   oneway                            1251 non-null   object
#  7   postal_code                       119 non-null    object
#  8   surface                           2371 non-null   object
#  9   junction                          11 non-null     object
#  10  trolley_wire                      317 non-null    object
#  11  layer                             106 non-null    object
#  12  smoothness                        282 non-null    object
#  13  bridge                            95 non-null     object
#  14  living_street                     1752 non-null   object
#  15  destination                       7 non-null      object
#  16  wikidata                          239 non-null    object
#  17  wikipedia                         235 non-null    object
#  18  side_road                         43 non-null     object
#  19  noname                            19 non-null     object
#  20  addr:postcode                     39 non-null     object
#  21  maxweight:hgv                     27 non-null     object
#  22  lanes:backward                    6 non-null      object
#  23  addr:suburb                       29 non-null     object
#  24  incline                           9 non-null      object
#  25  comment                           54 non-null     object
#  26  ref                               56 non-null     object
#  27  source:maxspeed                   63 non-null     object
#  28  service                           489 non-null    object
#  29  access                            216 non-null    object
#  30  hgv                               73 non-null     object
#  31  check_date                        1 non-null      object
#  32  name:de                           60 non-null     object
#  33  name:en                           67 non-null     object
#  34  name:fi                           54 non-null     object
#  35  official_name                     54 non-null     object
#  36  short_name                        54 non-null     object
#  37  destination:int_ref               2 non-null      object
#  38  destination:ref                   2 non-null      object
#  39  turn:lanes                        184 non-null    object
#  40  lanes:psv                         23 non-null     object
#  41  loc_name                          1 non-null      object
#  42  note                              18 non-null     object
#  43  parking:condition:right           2 non-null      object
#  44  parking:lane:left                 2 non-null      object
#  45  parking:lane:right                4 non-null      object
#  46  name:ru                           21 non-null     object
#  47  hazmat                            3 non-null      object
#  48  vehicle                           38 non-null     object
#  49  old_ref                           15 non-null     object
#  50  lanes:forward                     3 non-null      object
#  51  turn:lanes:forward                4 non-null      object
#  52  maxheight                         20 non-null     object
#  53  maxspeed:type                     1 non-null      object
#  54  old_name                          11 non-null     object
#  55  source                            59 non-null     object
#  56  covered                           98 non-null     object
#  57  sidewalk                          7 non-null      object
#  58  tunnel                            49 non-null     object
#  59  check_date:surface                8 non-null      object
#  60  description                       3 non-null      object
#  61  motorcycle                        1 non-null      object
#  62  fixme                             4 non-null      object
#  63  bridge:movable                    4 non-null      object
#  64  end_date                          2 non-null      object
#  65  length                            2 non-null      object
#  66  maxweight                         4 non-null      object
#  67  name:fr                           2 non-null      object
#  68  psv                               3 non-null      object
#  69  addr:full                         1 non-null      object
#  70  material                          1 non-null      object
#  71  addr:place                        3 non-null      object
#  72  source:name                       3 non-null      object
#  73  maxwidth                          1 non-null      object
#  74  construction                      9 non-null      object
#  75  embankment                        5 non-null      object
#  76  opening_date                      1 non-null      object
#  77  oneway:note                       2 non-null      object
#  78  turn                              4 non-null      object
#  79  type                              1 non-null      object
#  80  lanes:reversible                  4 non-null      object
#  81  proposed                          3 non-null      object
#  82  turn:lanes:backward               3 non-null      object
#  83  was:oneway                        4 non-null      object
#  84  parking:lane:right:time_interval  2 non-null      object
#  85  motor_vehicle                     8 non-null      object
#  86  placement                         2 non-null      object
#  87  busway                            2 non-null      object
#  88  cycleway:right                    2 non-null      object
#  89  bus                               12 non-null     object
#  90  bicycle                           4 non-null      object
#  91  horse                             4 non-null      object
#  92  footway                           2 non-null      object
#  93  noexit                            3 non-null      object
# dtypes: object(94)
# memory usage: 4.5+ MB

# %%
extract_tags = ['name']  # добавляем "name"

gdf_streets = gdf_streets.join(tags[extract_tags])
gdf_streets
# Out:
#      type         id                                               tags  \
# 0     way    4078548  {'foot': 'no', 'highway': 'residential', 'lane...
# 1     way    4454334  {'highway': 'tertiary', 'junction': 'roundabou...
# 2     way    4454660  {'foot': 'no', 'highway': 'primary', 'lanes': ...
# 3     way    4454692  {'highway': 'unclassified', 'lanes': '2', 'lit...
# 4     way    4455562  {'highway': 'secondary', 'lanes': '2', 'layer'...
# ...   ...        ...                                                ...
# 6316  way  981878572                             {'highway': 'service'}
# 6317  way  982791402       {'highway': 'service', 'surface': 'asphalt'}
# 6318  way  982791403  {'highway': 'residential', 'lanes': '1', 'lit'...
# 6319  way  982791404  {'highway': 'residential', 'lanes': '1', 'lit'...
# 6320  way  982791405  {'highway': 'residential', 'lanes': '2', 'lit'...
#
#                                                geometry  \
# 0     LINESTRING (3385685.754 8387961.891, 3385692.2...
# 1     LINESTRING (3388641.888 8396122.519, 3388624.9...
# 2     LINESTRING (3388144.278 8393976.488, 3388156.8...
# 3     LINESTRING (3386659.454 8393215.475, 3386629.8...
# 4     LINESTRING (3390821.701 8403547.048, 3390778.0...
# ...                                                 ...
# 6316  LINESTRING (3390484.437 8390881.717, 3390544.7...
# 6317  LINESTRING (3390016.116 8405605.740, 3390030.0...
# 6318  LINESTRING (3390016.116 8405605.740, 3390104.3...
# 6319  LINESTRING (3389902.759 8405833.105, 3390016.1...
# 6320  LINESTRING (3389725.572 8406231.547, 3389622.1...
#
#                          name
# 0           Шепетовская улица
# 1     Екатерининский проспект
# 2        проспект Энергетиков
# 3                         NaN
# 4       Пискарёвский проспект
# ...                       ...
# 6316                      NaN
# 6317                      NaN
# 6318         проспект Маршака
# 6319         проспект Маршака
# 6320         проспект Маршака
#
# [6321 rows x 5 columns]

# %%
gdf_streets.dropna(
    how="all",  # удалить если отсутствуют значения во всех указанных столбцах
    subset=["name"],  # столбцы, в которых надо искать пропуски
    inplace=True
)
gdf_streets
# Out:
#      type         id                                               tags  \
# 0     way    4078548  {'foot': 'no', 'highway': 'residential', 'lane...
# 1     way    4454334  {'highway': 'tertiary', 'junction': 'roundabou...
# 2     way    4454660  {'foot': 'no', 'highway': 'primary', 'lanes': ...
# 4     way    4455562  {'highway': 'secondary', 'lanes': '2', 'layer'...
# 5     way    4455658  {'highway': 'unclassified', 'lanes': '1', 'lit...
# ...   ...        ...                                                ...
# 6313  way  979810037  {'highway': 'tertiary', 'lanes': '2', 'lit': '...
# 6314  way  979810038  {'highway': 'tertiary', 'lanes': '2', 'lit': '...
# 6318  way  982791403  {'highway': 'residential', 'lanes': '1', 'lit'...
# 6319  way  982791404  {'highway': 'residential', 'lanes': '1', 'lit'...
# 6320  way  982791405  {'highway': 'residential', 'lanes': '2', 'lit'...
#
#                                                geometry  \
# 0     LINESTRING (3385685.754 8387961.891, 3385692.2...
# 1     LINESTRING (3388641.888 8396122.519, 3388624.9...
# 2     LINESTRING (3388144.278 8393976.488, 3388156.8...
# 4     LINESTRING (3390821.701 8403547.048, 3390778.0...
# 5     LINESTRING (3388626.448 8394297.512, 3388806.4...
# ...                                                 ...
# 6313  LINESTRING (3395385.199 8385316.349, 3395302.6...
# 6314  LINESTRING (3395270.184 8385325.237, 3395300.5...
# 6318  LINESTRING (3390016.116 8405605.740, 3390104.3...
# 6319  LINESTRING (3389902.759 8405833.105, 3390016.1...
# 6320  LINESTRING (3389725.572 8406231.547, 3389622.1...
#
#                           name
# 0            Шепетовская улица
# 1      Екатерининский проспект
# 2         проспект Энергетиков
# 4        Пискарёвский проспект
# 5     проспект Маршала Блюхера
# ...                        ...
# 6313           Хасанская улица
# 6314           Хасанская улица
# 6318          проспект Маршака
# 6319          проспект Маршака
# 6320          проспект Маршака
#
# [1340 rows x 5 columns]

# %%
# проверка наличия дубликатов по полям "id", "geometry", "name"
gdf_streets.duplicated(subset = ["id", "geometry", "name"]).value_counts()
# Out:
# False    1340
# dtype: int64

# %%
# уникальные значения
gdf_streets["name"].is_unique
# Out:
# False

# %%
#группировка геометрии по столбцу name и объединение геометрии в одну
gdf_streets = gdf_streets.dissolve(by="name")
gdf_streets
# Out:
#                                                                    geometry  \
# name
# 1-й Охтинский путепровод  LINESTRING (3385032.231 8389412.855, 3385026.9...
# 1-я Жерновская улица      LINESTRING (3393354.687 8391674.447, 3393424.7...
# 1-я Поперечная улица      LINESTRING (3400575.014 8394720.248, 3400536.9...
# 1-я линия                 LINESTRING (3400408.291 8394100.825, 3400263.2...
# 2-й Охтинский путепровод  LINESTRING (3385001.317 8388918.283, 3384996.1...
# ...                                                                     ...
# улица Стасовой            MULTILINESTRING ((3387289.000 8392529.340, 338...
# улица Стахановцев         MULTILINESTRING ((3384905.081 8383712.036, 338...
# улица Химиков             MULTILINESTRING ((3391832.939 8392062.738, 339...
# улица Электропультовцев   LINESTRING (3391151.752 8392350.049, 3391163.6...
# шоссе Революции           MULTILINESTRING ((3392118.529 8391880.655, 339...
#
#                          type         id  \
# name
# 1-й Охтинский путепровод  way  174878843
# 1-я Жерновская улица      way   35552052
# 1-я Поперечная улица      way   25762136
# 1-я линия                 way  222472806
# 2-й Охтинский путепровод  way  174878847
# ...                       ...        ...
# улица Стасовой            way    4459864
# улица Стахановцев         way   31366301
# улица Химиков             way   31380613
# улица Электропультовцев   way  172366132
# шоссе Революции           way   23377550
#
#                                                                        tags
# name
# 1-й Охтинский путепровод  {'bridge': 'yes', 'highway': 'service', 'layer...
# 1-я Жерновская улица      {'highway': 'residential', 'lanes': '1', 'lit'...
# 1-я Поперечная улица      {'addr:suburb': 'Ново-Ковалёво', 'highway': 'r...
# 1-я линия                 {'addr:suburb': 'Ново-Ковалёво', 'highway': 'r...
# 2-й Охтинский путепровод  {'bridge': 'yes', 'highway': 'service', 'layer...
# ...                                                                     ...
# улица Стасовой            {'highway': 'residential', 'lanes': '1', 'lit'...
# улица Стахановцев         {'foot': 'no', 'highway': 'tertiary', 'lanes':...
# улица Химиков             {'foot': 'no', 'highway': 'tertiary', 'lanes':...
# улица Электропультовцев   {'highway': 'unclassified', 'lanes': '1', 'lit...
# шоссе Революции           {'foot': 'no', 'highway': 'secondary', 'lanes'...
#
# [207 rows x 4 columns]

# %%
# переименуем индекс
gdf_streets.index.rename("Название улицы", inplace=True)
gdf_streets.head()
# Out:
#                                                                    geometry  \
# Название улицы
# 1-й Охтинский путепровод  LINESTRING (3385032.231 8389412.855, 3385026.9...
# 1-я Жерновская улица      LINESTRING (3393354.687 8391674.447, 3393424.7...
# 1-я Поперечная улица      LINESTRING (3400575.014 8394720.248, 3400536.9...
# 1-я линия                 LINESTRING (3400408.291 8394100.825, 3400263.2...
# 2-й Охтинский путепровод  LINESTRING (3385001.317 8388918.283, 3384996.1...
#
#                          type         id  \
# Название улицы
# 1-й Охтинский путепровод  way  174878843
# 1-я Жерновская улица      way   35552052
# 1-я Поперечная улица      way   25762136
# 1-я линия                 way  222472806
# 2-й Охтинский путепровод  way  174878847
#
#                                                                        tags
# Название улицы
# 1-й Охтинский путепровод  {'bridge': 'yes', 'highway': 'service', 'layer...
# 1-я Жерновская улица      {'highway': 'residential', 'lanes': '1', 'lit'...
# 1-я Поперечная улица      {'addr:suburb': 'Ново-Ковалёво', 'highway': 'r...
# 1-я линия                 {'addr:suburb': 'Ново-Ковалёво', 'highway': 'r...
# 2-й Охтинский путепровод  {'bridge': 'yes', 'highway': 'service', 'layer...

# %%
# удалим столбцы
drop_columns = [
    "id",
    "type",
    "tags",
]
gdf_streets.drop(columns=drop_columns, inplace=True)
gdf_streets.head()
# Out:
#                                                                    geometry
# Название улицы
# 1-й Охтинский путепровод  LINESTRING (3385032.231 8389412.855, 3385026.9...
# 1-я Жерновская улица      LINESTRING (3393354.687 8391674.447, 3393424.7...
# 1-я Поперечная улица      LINESTRING (3400575.014 8394720.248, 3400536.9...
# 1-я линия                 LINESTRING (3400408.291 8394100.825, 3400263.2...
# 2-й Охтинский путепровод  LINESTRING (3385001.317 8388918.283, 3384996.1...

# %%
gdf_streets.explore(tiles=TILES)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_83559241291d555541f174d853f22ac7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_83559241291d555541f174d853f22ac7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_83559241291d555541f174d853f22ac7 = L.map(
#                 &quot;map_83559241291d555541f174d853f22ac7&quot;,
#                 {
#                     center: [59.9779483, 30.47454595],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_83559241291d555541f174d853f22ac7);
#
#
#
#
#
#             var tile_layer_bd7d76efbdfe4703a6cfc18490b99345 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_83559241291d555541f174d853f22ac7);
#
#
#             map_83559241291d555541f174d853f22ac7.fitBounds(
#                 [[59.91595980000001, 30.3894545], [60.03993679999999, 30.5596374]],
#                 {}
#             );
#
#
#         function geo_json_36589b24f174f29f7c84d6b87d649e16_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_36589b24f174f29f7c84d6b87d649e16_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_36589b24f174f29f7c84d6b87d649e16_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_36589b24f174f29f7c84d6b87d649e16_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_36589b24f174f29f7c84d6b87d649e16_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_36589b24f174f29f7c84d6b87d649e16.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_36589b24f174f29f7c84d6b87d649e16_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_36589b24f174f29f7c84d6b87d649e16 = L.geoJson(null, {
#                 onEachFeature: geo_json_36589b24f174f29f7c84d6b87d649e16_onEachFeature,
#
#                 style: geo_json_36589b24f174f29f7c84d6b87d649e16_styler,
#                 pointToLayer: geo_json_36589b24f174f29f7c84d6b87d649e16_pointToLayer
#         });
#
#         function geo_json_36589b24f174f29f7c84d6b87d649e16_add (data) {
#             geo_json_36589b24f174f29f7c84d6b87d649e16
#                 .addData(data)
#                 .addTo(map_83559241291d555541f174d853f22ac7);
#         }
#             geo_json_36589b24f174f29f7c84d6b87d649e16_add({&quot;bbox&quot;: [30.3894545, 59.91595980000001, 30.5596374, 60.03993679999999], &quot;features&quot;: [{&quot;bbox&quot;: [30.408214900000004, 59.95321539999999, 30.408261899999992, 59.9535918], &quot;geometry&quot;: {&quot;coordinates&quot;: [[30.408261899999992, 59.9535918], [30.408214900000004, 59.95321539999999]], &quot;type&quot;: &quot;LineString&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;\u041d\u0430\u0437\u0432\u0430\u043d\u0438\u0435 \u0443\u043b\u0438\

# %% [markdown]
# ## 4 Объекты культурного наследия

# %% [markdown]
# ### 4.1 Загрузка объектов культурного наследия

# %%
gdf_kgiop_objects = gpd.read_file(KGIOP_FILE_URL, mask=territory) # фильтр объектов по маске геометрии территории, полученной ранее
gdf_kgiop_objects
# Out:
#        id                                      ensemble_name  \
# 0    2733                                                  —
# 1    2734  Казармы служителей Охтинского Порохового завод...
# 2    2735  Казармы служителей Охтинского Порохового завод...
# 3    2736                                                  —
# 4    2737                                                  —
# ..    ...                                                ...
# 113  2893                                                  —
# 114  2894                                                  —
# 115  2895                                                  —
# 116  9659                                                  —
# 117  9666                                                  —
#
#                                            object_name occurrence_time  \
# 0    Казармы служителей Охтинского Порохового завод...      20 в. нач.
# 1                                              Казарма      20 в. нач.
# 2                                              Казарма      20 в. нач.
# 3                            Доходный дом П.И. Иванова       1906-1907
# 4                                 Особняк П.И. Иванова            1901
# ..                                                 ...             ...
# 113          Памятник общественному деятелю Гроту К.К.            1906
# 114  Дом призрения бедных духовного звания при Боль...               —
# 115  Триумфальные пилоны в честь защитников Ленингр...       1952-1953
# 116  Участок сохранившегося культурного слоя с сохр...               —
# 117  Участок сохранившегося культурного слоя ХVII-Х...               —
#
#                                        object_location  \
# 0    2-я Жерновская ул., 58, лит. А; 2-я Жерновская...
# 1                       2-я Жерновская ул., 58, лит. А
# 2                       2-я Жерновская ул., 64, лит. А
# 3    Большая Пороховская ул., 16; Среднеохтинский п...
# 4                          Большая Пороховская ул., 18
# ..                                                 ...
# 113                                    Шаумяна пр., 44
# 114                        Шепетовская ул., 14, лит. А
# 115  Коммуны ул., д.50, сооружение 1, лит. А; д.51,...
# 116  северная часть квартала 11 М.Охты (Новочеркасс...
# 117  Малоохтинский пр., д. 8, кадастровый номер 78:...
#
#                                    historical_category  \
# 0               выявленный объект культурного наследия
# 1               выявленный объект культурного наследия
# 2               выявленный объект культурного наследия
# 3               выявленный объект культурного наследия
# 4               выявленный объект культурного наследия
# ..                                                 ...
# 113  объект культурного наследия федерального значения
# 114  объект культурного наследия регионального знач...
# 115  объект культурного наследия регионального знач...
# 116             выявленный объект культурного наследия
# 117             выявленный объект культурного наследия
#
#                                          normative_act object_type  \
# 0         Приказ председателя КГИОП № 15 от 20.02.2001    Ансамбль
# 1         Приказ председателя КГИОП № 15 от 20.02.2001    Памятник
# 2         Приказ председателя КГИОП № 15 от 20.02.2001    Памятник
# 3         Приказ председателя КГИОП № 15 от 20.02.2001    Памятник
# 4         Приказ председателя КГИОП № 15 от 20.02.2001    Памятник
# ..                                                 ...         ...
# 113  Постановление Правительства РФ № 527 от 10.07....    Памятник
# 114           Распоряжение КГИОП № 10-21 от 22.06.2009    Памятник
# 115          Распоряжение КГИОП от 20.04.2016 № 10-139    Памятник
# 116           Распоряжение КГИОП № 342-р от 21.10.2020    Памятник
# 117           Распоряжение КГИОП № 419-р от 24.11.2020    Памятник
#
#                             geometry
# 0    POINT (3393917.541 8391682.542)
# 1    POINT (3393942.031 8391697.888)
# 2    POINT (3393893.051 8391664.084)
# 3    POINT (3385859.012 8389439.579)
# 4    POINT (3385918.345 8389472.261)
# ..                               ...
# 113  POINT (3386904.302 8383501.147)
# 114  POINT (3386353.938 8387883.003)
# 115  POINT (3394240.145 8390795.015)
# 116  POINT (3384950.867 8384360.913)
# 117  POINT (3384738.024 8385958.745)
#
# [118 rows x 9 columns]

# %% [markdown]
# ### 4.2 Обработка объектов культурного наследия

# %%
# оставляем только столбцы object_name, object_location, object_type,
drop_columns = [
    "id",
    "ensemble_name",
    "occurrence_time",
    "historical_category",
    "normative_act"
]
gdf_kgiop_objects.drop(columns=drop_columns, inplace=True)
gdf_kgiop_objects.head()
# Out:
#                                          object_name  \
# 0  Казармы служителей Охтинского Порохового завод...
# 1                                            Казарма
# 2                                            Казарма
# 3                          Доходный дом П.И. Иванова
# 4                               Особняк П.И. Иванова
#
#                                      object_location object_type  \
# 0  2-я Жерновская ул., 58, лит. А; 2-я Жерновская...    Ансамбль
# 1                     2-я Жерновская ул., 58, лит. А    Памятник
# 2                     2-я Жерновская ул., 64, лит. А    Памятник
# 3  Большая Пороховская ул., 16; Среднеохтинский п...    Памятник
# 4                        Большая Пороховская ул., 18    Памятник
#
#                           geometry
# 0  POINT (3393917.541 8391682.542)
# 1  POINT (3393942.031 8391697.888)
# 2  POINT (3393893.051 8391664.084)
# 3  POINT (3385859.012 8389439.579)
# 4  POINT (3385918.345 8389472.261)

# %%
# переименовали столбцы object_name, object_location, object_type в русские названия
gdf_kgiop_objects = gdf_kgiop_objects.rename(columns ={'object_name': 'Объект культурного наследия', 'object_location': 'Адрес', 'object_type': 'Тип'})
gdf_kgiop_objects.head()
# Out:
#                          Объект культурного наследия  \
# 0  Казармы служителей Охтинского Порохового завод...
# 1                                            Казарма
# 2                                            Казарма
# 3                          Доходный дом П.И. Иванова
# 4                               Особняк П.И. Иванова
#
#                                                Адрес       Тип  \
# 0  2-я Жерновская ул., 58, лит. А; 2-я Жерновская...  Ансамбль
# 1                     2-я Жерновская ул., 58, лит. А  Памятник
# 2                     2-я Жерновская ул., 64, лит. А  Памятник
# 3  Большая Пороховская ул., 16; Среднеохтинский п...  Памятник
# 4                        Большая Пороховская ул., 18  Памятник
#
#                           geometry
# 0  POINT (3393917.541 8391682.542)
# 1  POINT (3393942.031 8391697.888)
# 2  POINT (3393893.051 8391664.084)
# 3  POINT (3385859.012 8389439.579)
# 4  POINT (3385918.345 8389472.261)

# %%
gdf_kgiop_objects.explore(tiles=TILES)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b4f9bb1f661057a0973a3f6259c2479e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b4f9bb1f661057a0973a3f6259c2479e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b4f9bb1f661057a0973a3f6259c2479e = L.map(
#                 &quot;map_b4f9bb1f661057a0973a3f6259c2479e&quot;,
#                 {
#                     center: [59.955364, 30.464963999999995],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_b4f9bb1f661057a0973a3f6259c2479e);
#
#
#
#
#
#             var tile_layer_ebf827bf9627795c9ca52e8b159c7810 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b4f9bb1f661057a0973a3f6259c2479e);
#
#
#             map_b4f9bb1f661057a0973a3f6259c2479e.fitBounds(
#                 [[59.924715000000006, 30.400423999999994], [59.98601300000001, 30.529504]],
#                 {}
#             );
#
#
#         function geo_json_15c5fc960155c85a0fe97e466629e110_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_15c5fc960155c85a0fe97e466629e110_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_15c5fc960155c85a0fe97e466629e110_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_15c5fc960155c85a0fe97e466629e110_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_15c5fc960155c85a0fe97e466629e110_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         geo_json_15c5fc960155c85a0fe97e466629e110.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_15c5fc960155c85a0fe97e466629e110_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_15c5fc960155c85a0fe97e466629e110 = L.geoJson(null, {
#                 onEachFeature: geo_json_15c5fc960155c85a0fe97e466629e110_onEachFeature,
#
#                 style: geo_json_15c5fc960155c85a0fe97e466629e110_styler,
#                 pointToLayer: geo_json_15c5fc960155c85a0fe97e466629e110_pointToLayer
#         });
#
#         function geo_json_15c5fc960155c85a0fe97e466629e110_add (data) {
#             geo_json_15c5fc960155c85a0fe97e466629e110
#                 .addData(data)
#                 .addTo(map_b4f9bb1f661057a0973a3f6259c2479e);
#         }
#             geo_json_15c5fc960155c85a0fe97e466629e110_add({&quot;bbox&quot;: [30.400423999999994, 59.924715000000006, 30.529504, 59.98601300000001], &quot;features&quot;: [{&quot;bbox&quot;: [30.488080000000004, 59.963798999999995, 30.488080000000004, 59.963798999999995], &quot;geometry&quot;: {&quot;coordinates&quot;: [30.488080000000004, 59.963798999999995], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;\u0410\u0434\u0440\u0435\u0441&quot;: &quot;2-\u044f \u0416\u0435\u0440\u043d

# %% [markdown]
# ### 4.3 Количество объектов культурного наследия, попадающее в буффер улицы

# %%
# создаем буфер
STREET_BUFFER = 100

def get_contains_kgiop_objects(street) -> int:
    """ Функция для подсчета количества объектов культурного наследия попадающих в буффер улицы"""
    return sum(gdf_kgiop_objects["geometry"].within(street.buffer(STREET_BUFFER)))


gdf_streets["contains_kgiop_objects"] = gdf_streets["geometry"].apply(get_contains_kgiop_objects)
gdf_streets.nlargest(5, "contains_kgiop_objects")
# Out:
#                                                                    geometry  \
# Название улицы
# Большеохтинский проспект  MULTILINESTRING ((3385140.255 8387624.984, 338...
# Малоохтинский проспект    MULTILINESTRING ((3384040.196 8383835.267, 338...
# Новочеркасский проспект   MULTILINESTRING ((3385451.037 8383969.096, 338...
# Уральская дорожка         MULTILINESTRING ((3387289.923 8388192.114, 338...
# шоссе Революции           MULTILINESTRING ((3392118.529 8391880.655, 339...
#
#                           contains_kgiop_objects
# Название улицы
# Большеохтинский проспект                       6
# Малоохтинский проспект                         5
# Новочеркасский проспект                        5
# Уральская дорожка                              5
# шоссе Революции                                5

# %%
gdf_streets.explore("contains_kgiop_objects", tiles=TILES)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36d94de00a31e0dfbec15713ac0f0dc4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36d94de00a31e0dfbec15713ac0f0dc4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36d94de00a31e0dfbec15713ac0f0dc4 = L.map(
#                 &quot;map_36d94de00a31e0dfbec15713ac0f0dc4&quot;,
#                 {
#                     center: [59.9779483, 30.47454595],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_36d94de00a31e0dfbec15713ac0f0dc4);
#
#
#
#
#
#             var tile_layer_aecf0691336e2310f6d5461c63589172 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_36d94de00a31e0dfbec15713ac0f0dc4);
#
#
#             map_36d94de00a31e0dfbec15713ac0f0dc4.fitBounds(
#                 [[59.91595980000001, 30.3894545], [60.03993679999999, 30.5596374]],
#                 {}
#             );
#
#
#         function geo_json_31703a3a31c2be534e4d60ca4f51390c_styler(feature) {
#             switch(feature.id) {
#                 case &quot;5&quot;: case &quot;29&quot;: case &quot;32&quot;: case &quot;75&quot;: case &quot;187&quot;:
#                     return {&quot;color&quot;: &quot;#21908d&quot;, &quot;fillColor&quot;: &quot;#21908d&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;34&quot;:
#                     return {&quot;color&quot;: &quot;#fde725&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;35&quot;: case &quot;62&quot;: case &quot;68&quot;: case &quot;90&quot;: case &quot;106&quot;: case &quot;111&quot;: case &quot;116&quot;: case &quot;128&quot;: case &quot;138&quot;: case &quot;142&quot;: case &quot;156&quot;: case &quot;178&quot;: case &quot;185&quot;: case &quot;189&quot;: case &quot;204&quot;:
#                     return {&quot;color&quot;: &quot;#443983&quot;, &quot;fillColor&quot;: &quot;#443983&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;56&quot;:
#                     return {&quot;color&quot;: &quot;#35b779&quot;, &quot;fillColor&quot;: &quot;#35b779&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;74&quot;: case &quot;113&quot;: case &quot;134&quot;: case &quot;160&quot;: case &quot;172&quot;: case &quot;198&quot;:
#                     return {&quot;color&quot;: &quot;#31688e&quot;, &quot;fillColor&quot;: &quot;#31688e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;92&quot;: case &quot;103&quot;: case &quot;148&quot;: case &quot;206&quot;:
#                     return {&quot;color&quot;: &quot;#90d743&quot;, &quot;fillColor&quot;: &quot;#90d743&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_31703a3a31c2be534e4d60ca4f51390c_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_31703a3a31c2be534e4d60ca4f51390c_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_31703a3a31c2be534e4d60ca4f51390c

# %%
gdf_streets["density"] = gdf_streets["contains_kgiop_objects"] / gdf_streets.length

select_columns = []
gdf_streets.nlargest(5, "density")
# Out:
#                                                                  geometry  \
# Название улицы
# Большой Ильинский мост  MULTILINESTRING ((3391992.838 8391901.138, 339...
# Конторская улица        LINESTRING (3385162.853 8387874.512, 3385175.1...
# Уральская дорожка       MULTILINESTRING ((3387289.923 8388192.114, 338...
# улица Помяловского      MULTILINESTRING ((3385033.088 8385957.390, 338...
# Берёзовая дорожка       LINESTRING (3386495.781 8388357.655, 3386630.5...
#
#                         contains_kgiop_objects   density
# Название улицы
# Большой Ильинский мост                       1  0.005640
# Конторская улица                             3  0.005638
# Уральская дорожка                            5  0.004645
# улица Помяловского                           2  0.004028
# Берёзовая дорожка                            3  0.003725

# %%
# переименовать столбцы contains_kgiop_objects и density в русские названия
gdf_streets = gdf_streets.rename(columns ={'contains_kgiop_objects': 'Количество ОКН', 'density': 'Плотность'})

# %%
# уберем улицы, где нет объектов культурного наследия
gdf_streets = gdf_streets.loc[gdf_streets.loc[:,'Количество ОКН']>0]  # gdf_streets.loc[gdf_streets['Количество ОКН'] > 0]
gdf_streets.head(20)
# Out:
#                                                                     geometry  \
# Название улицы
# 2-я Жерновская улица       MULTILINESTRING ((3393793.008 8391638.241, 339...
# Берёзовая дорожка          LINESTRING (3386495.781 8388357.655, 3386630.5...
# Большая Пороховская улица  MULTILINESTRING ((3388222.992 8389322.413, 338...
# Большеохтинский проспект   MULTILINESTRING ((3385140.255 8387624.984, 338...
# Большой Ильинский мост     MULTILINESTRING ((3391992.838 8391901.138, 339...
# Ильинская слобода          MULTILINESTRING ((3392005.450 8391883.835, 339...
# КАД                        MULTILINESTRING ((3394881.724 8396149.223, 339...
# Ковалёвская улица          MULTILINESTRING ((3395555.774 8394603.666, 339...
# Конная дорога              LINESTRING (3387262.149 8388623.636, 3387333.6...
# Конторская улица           LINESTRING (3385162.853 8387874.512, 3385175.1...
# Малоохтинская набережная   MULTILINESTRING ((3384673.782 8387271.378, 338...
# Малоохтинский проспект     MULTILINESTRING ((3384040.196 8383835.267, 338...
# Новочеркасский проспект    MULTILINESTRING ((3385451.037 8383969.096, 338...
# Окраинная улица            LINESTRING (3398411.865 8396372.446, 3398392.3...
# Отечественная улица        MULTILINESTRING ((3393567.241 8390455.399, 339...
# Партизанская улица         MULTILINESTRING ((3386378.540 8387592.332, 338...
# Перевозный переулок        MULTILINESTRING ((3385849.872 8384745.086, 338...
# Ржевская улица             MULTILINESTRING ((3395536.850 8395078.639, 339...
# Рябовское шоссе            MULTILINESTRING ((3396557.204 8395949.081, 339...
# Смоленская дорожка         LINESTRING (3387279.426 8388186.445, 3387205.1...
#
#                            Количество ОКН  Плотность
# Название улицы
# 2-я Жерновская улица                    3   0.001787
# Берёзовая дорожка                       3   0.003725
# Большая Пороховская улица               3   0.000387
# Большеохтинский проспект                6   0.001444
# Большой Ильинский мост                  1   0.005640
# Ильинская слобода                       4   0.003543
# КАД                                     1   0.000026
# Ковалёвская улица                       1   0.000354
# Конная дорога                           2   0.002156
# Конторская улица                        3   0.005638
# Малоохтинская набережная                1   0.000128
# Малоохтинский проспект                  5   0.000558
# Новочеркасский проспект                 5   0.000443
# Окраинная улица                         1   0.001126
# Отечественная улица                     1   0.001215
# Партизанская улица                      2   0.000542
# Перевозный переулок                     1   0.000573
# Ржевская улица                          1   0.000468
# Рябовское шоссе                         2   0.000157
# Смоленская дорожка                      1   0.001159

# %%
# выведем красивую карту с градацией объектов
m = gdf_streets.explore("Количество ОКН", tiles=TILES)
m = territory.explore(m=m, style_kwds={"fill": False, "weight": 5})

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4a7c511e49df98a3aaaae6ade24827a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4a7c511e49df98a3aaaae6ade24827a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4a7c511e49df98a3aaaae6ade24827a0 = L.map(
#                 &quot;map_4a7c511e49df98a3aaaae6ade24827a0&quot;,
#                 {
#                     center: [59.97822205, 30.469519849999998],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#             L.control.scale().addTo(map_4a7c511e49df98a3aaaae6ade24827a0);
#
#
#
#
#
#             var tile_layer_5afce3927c61350d440b272837e26caf = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca target=\&quot;_blank\&quot; href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca target=\&quot;_blank\&quot; href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_4a7c511e49df98a3aaaae6ade24827a0);
#
#
#             map_4a7c511e49df98a3aaaae6ade24827a0.fitBounds(
#                 [[59.9165073, 30.398772599999997], [60.03993679999999, 30.5402671]],
#                 {}
#             );
#
#
#         function geo_json_763131181d452a5bf1107f19ff694d28_styler(feature) {
#             switch(feature.id) {
#                 case &quot;0&quot;: case &quot;1&quot;: case &quot;2&quot;: case &quot;9&quot;: case &quot;27&quot;:
#                     return {&quot;color&quot;: &quot;#2a788e&quot;, &quot;fillColor&quot;: &quot;#2a788e&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;3&quot;:
#                     return {&quot;color&quot;: &quot;#fde725&quot;, &quot;fillColor&quot;: &quot;#fde725&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;#22a884&quot;, &quot;fillColor&quot;: &quot;#22a884&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;8&quot;: case &quot;15&quot;: case &quot;18&quot;: case &quot;23&quot;: case &quot;24&quot;: case &quot;29&quot;:
#                     return {&quot;color&quot;: &quot;#414487&quot;, &quot;fillColor&quot;: &quot;#414487&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 case &quot;11&quot;: case &quot;12&quot;: case &quot;21&quot;: case &quot;31&quot;:
#                     return {&quot;color&quot;: &quot;#7ad151&quot;, &quot;fillColor&quot;: &quot;#7ad151&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#                 default:
#                     return {&quot;color&quot;: &quot;#440154&quot;, &quot;fillColor&quot;: &quot;#440154&quot;, &quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_763131181d452a5bf1107f19ff694d28_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_763131181d452a5bf1107f19ff694d28_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_76313

# %% [markdown]
# ## 5 Выводы

# %%
total_kgiop_objects = gdf_streets['Количество ОКН'].sum()
print(f'Общее количество объектов культурного наследия на территории {TERRITORY_NAME} равно {total_kgiop_objects}.')

gdf_streets_kgiop_max = gdf_streets.nlargest(5, "Количество ОКН")
street_kgiop_max = gdf_streets_kgiop_max.index[0] #Самое большое количество объектов у улицы  или street_kgiop_max = gdf_streets_kgiop.indmax()
print(f'Самое большое количесво объектов у улицы - {street_kgiop_max}.')

top_5 = []
for address in gdf_streets.head().index:
    top_5.append(address)  # TODO list mprehenshion
top_5 = ', '.join(top_5)  # ', '.join(gdf_streets_kgiop_max.index)
print(f'Топ 5 улиц: {top_5}.')

density_avg = gdf_streets['Плотность'].mean()
print(f'Среднее количество объектов культурного наследия на одну улицу равно {density_avg.round(5)}.')
# Out:
# Общее количество объектов культурного наследия на территории Красногвардейский район, Санкт-Петербург равно 72.
# Самое большое количесво объектов у улицы - Большеохтинский проспект.
# Топ 5 улиц: 2-я Жерновская улица, Берёзовая дорожка, Большая Пороховская улица, Большеохтинский проспект, Большой Ильинский мост.
# Среднее количество объектов культурного наследия на одну улицу равно 0.0014.

# %% [markdown]
# ## 6 Сохранение файлов в формате geojson

# %%
gdf_kgiop_objects.to_crs(4236, inplace = True)

gdf_kgiop_objects['lon'] = gdf_kgiop_objects.geometry.x
gdf_kgiop_objects['lat'] = gdf_kgiop_objects.geometry.y

gdf_kgiop_objects.to_file('kgiop.geojson', driver='GeoJSON')

# %%
gdf_streets.to_crs(4236, inplace = True)

gdf_streets['lon'] = gdf_kgiop_objects.geometry.x
gdf_streets['lat'] = gdf_kgiop_objects.geometry.y

gdf_streets.to_file('streets_with_contains_kgiop.geojson', driver='GeoJSON')
